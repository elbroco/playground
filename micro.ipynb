# %%
# micro part 2

import matplotlib.pyplot as plt 
import numpy as np

u = 6
x = np.linspace(0,50,50)
y = ((u**2)/(x-5))+7

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np

u = 50
x = np.linspace(0,50,50)
y = ((u-(2*x))/3)

plt.plot(x,y)
plt.show()
